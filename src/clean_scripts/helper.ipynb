# %% [markdown]
# # Data file description
#
# This project uses three cleaned data files stored in `... /... /raw_data/clean_data/` directory.
# Each file is in CSV format and contains four columns of information:
# - **Year**: the year of invention or discovery
# - **Country**: the country where the invention or discovery is located
# - **Name of Invention**: the name of the invention or discovery
# - **Name of Inventor**: the name of the inventor or discoverer
# - **Category**: Category of Field
#
# The list of files is as follows:
# - `clean_data_yann_1.csv`
# - `clean_data_yann_2.csv`
# - `clean_data_yann_3.csv`
#
# Translated with DeepL.com (free version)

# %%
# Cell 2: Importing libraries and reading data
import pandas as pd

# path1 = '../../raw_data/clean_data/clean_data_yann_1.csv'
# path2 = '../../raw_data/clean_data/clean_data_yann_2.csv'
# path3 = '../../raw_data/clean_data/clean_data_yann_3.csv'
path4 = '../../raw_data/clean_data/clean_data_balam.csv'

# df1 = pd.read_csv(path1)
# df2 = pd.read_csv(path2)
# df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)

# %%
# Cell 3: Merge the data, extract the de-duplicate Category and count it.
df_all = pd.concat([df4], ignore_index=True)
categories = df_all['Category'].drop_duplicates().tolist()
count = len(categories)

print(f"There are {count} of different Categories after de-duplication:")
for cat in categories:
    print(f"－ {cat}")
# Out:
# There are 151 of different Categories after de-duplication:
# － Music
# － Agricultural Machinery
# － Measurement Instrument
# － Metallurgical Engineering
# － Mechanical Engineering
# － Horology
# － Textile Machinery
# － Domestic Technology
# － Materials Technology
# － Refrigeration Technology
# － Electrical Engineering
# － Food Technology
# － Marine Navigation
# － Recreational Technology
# － Chemistry
# － Military Technology
# － Marine Technology
# － Firearms Technology
# － Aviation Technology
# － Optics
# － Safety Technology
# － Communication Technology
# － Immunology
# － Printing Technology
# － Battery Technology
# － Machine Tools
# － Transportation Engineering
# － Rocketry
# － Civil Engineering
# － Transportation
# － Construction Engineering
# － Medical Equipment
# － Assistive Technology
# － Photography
# － Renewable Energy
# － Biology
# － Computing
# － Electrochemistry
# － Communication Device
# － Polymer Material
# － Timekeeping Mechanism
# － Agricultural Implement
# － Communication System
# － Photographic Process
# － Chemical Discovery
# － Vehicle
# － Industrial Machinery
# － Chemical Process
# － Metallurgy
# － Structural Engineering
# － Musical Instrument
# － Explosive Technology
# － Medical Anaesthetic
# － Printing Machinery
# － Ammunition
# － Metallurgical Process
# － Industrial Process
# － Aeronautical Vehicle
# － Personal Accessory
# － Vertical Transportation
# － Vertical Transportation Safety
# － Aeronautical Device
# － Lighting Device
# － Chemical Safety Device
# － Railway Carriage
# － Engine
# － Scientific Theory
# － Kitchen Utensil
# － Home Appliance
# － Energy Storage Device
# － Personal Grooming
# － Sports Equipment
# － Firearm Technology
# － Metallurgical Furnace
# － Plastic Material
# － Flooring Material
# － Scientific Imaging
# － Security Device
# － Food Safety Process
# － Medical Instrument
# － Construction Material
# － Transport System
# － Office Equipment
# － Scientific Model
# － Transportation Safety Device
# － Vehicle Innovation
# － Packaging
# － Clothing
# － Astronomical Theory
# － Agricultural Fencing
# － Electromechanical Device
# － Audio Device
# － Cleaning Device
# － Machine Tool
# － Audio Recording Device
# － Audio Playback Device
# － Electric Motor
# － Marine Safety Equipment
# － Household Appliance
# － Textile Fiber
# － Turbine
# － Fuel
# － Chemical Element
# － Film Technology
# － Agricultural Engineering
# － Thermodynamics
# － Garment Technology
# － Medical Imaging
# － Nuclear Physics
# － Biochemistry
# － Pharmaceuticals
# － Telecommunications
# － Theoretical Physics
# － Automotive Technology
# － Electronics
# － Physics
# － Navigation Technology
# － Geology
# － Industrial Engineering
# － Biotechnology
# － Electronic Engineering
# － Climate Science
# － Aerospace Engineering
# － Cosmology
# － Astrophysics
# － Astronomy
# － Environmental Science
# － Nuclear Science
# － Diving Technology
# － Nuclear Weapons
# － Radiometric Dating
# － Audio Technology
# － Energy Technology
# － Computer Science
# － Software
# － Genetics
# － Genomics
# － Artificial Intelligence
# － Optical Storage
# － Semiconductor Technology
# － Laser Technology
# － Optoelectronics
# － Computer Interface
# － Digital Storage
# － Mobile Technology
# － Toys
# － Networking Technology
# － Computer Hardware
# － Nanotechnology
# － Information Technology
# － Particle Physics

# %%
# Cell 4: Extract and print unique countries
# Assuming df_all is already defined from the previous cell
# Get the 'Country' column, drop duplicate entries, and convert to a list
unique_countries = df_all['Country'].drop_duplicates().tolist()

# Count how many unique countries there are
country_count = len(unique_countries)

# Print the total number of unique countries
print(f"There are {country_count} unique countries in the dataset:")

# Print each country on its own line
for country in unique_countries:
    print(f"- {country}")
# Out:
# There are 75 unique countries in the dataset:
# - Germany
# - Austrian-American
# - United Kingdom
# - Croatia
# - USA
# - New Zealand
# - Netherlands
# - Austria
# - United Kingdom; Germany
# - Serbia
# - United Kingdom; USA
# - Canada
# - Australia
# - Germany; Austria
# - Japan
# - Austria; Netherlands
# - USA; Germany
# - Soviet Union
# - Austria; Sweden
# - Italy; Germany
# - Russia; USA
# - USA; Japan
# - USA; United Kingdom
# - Japan; USA
# - USA; Pakistan
# - Mexico; USA
# - Australia; Switzerland
# - USA; France
# - Germany; United Kingdom
# - France
# - Switzerland
# - USA; International
# - England
# - Sweden
# - Italy
# - Denmark
# - Germany; USA
# - France; Germany; United Kingdom
# - Czech
# - Russia
# - Scotland
# - Germany; Denmark; Germany; Germany; Austria
# - Belgium
# - Britain
# - USA; USA; Canada
# - Poland
# - USA; England
# - India
# - Ireland
# - Hungary
# - Wales
# - Germany; Canada
# - Germany; France
# - United States
# - United Kingdom; United States
# - Bulgaria
# - United States; France
# - Poland; France
# - Norway
# - Belgium; United States
# - United Kingdom; France
# - United Kingdom; Australia
# - Hungarian; British
# - Egyptian; Korean
# - United States; China
# - United Kingdom; United States; Israel
# - United States; Italy
# - United States; France; Japan
# - United States; United Kingdom
# - Japan; Dutch
# - Netherlands; Japan
# - Finland
# - South Korea
# - Multiple
# - United States; Germany

# %%
# 1. Load the final cleaned CSV
df_final = pd.read_csv('../../raw_data/clean_data/clean_data_dd.csv')

# 2. Filter rows where General_Category == 'Other'
others = df_final[df_final['General_Category'] == 'Other']

# 3. Report and inspect
print(f"Found {len(others)} rows with General_Category == 'Other':")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

display(others)
# Out:
# Found 69 rows with General_Category == 'Other':
#      Year                  Country                       Name of Invention  \
# 7    1725                    China                        Clock Mechanical
# 20   1745              Netherlands              Leyden Jar; The Leyden Jar
# 24   1752            United States                           Lightning Rod
# 40   1769                   France                steamdriven gun carriage
# 58   1783                   France                  Manned Hot Air Balloon
# 61   1783                   France                        Modern Parachute
# 84   1799                    Italy                             The Battery
# 88   1800                    Italy                            Voltaic Pile
# 91   1802           United Kingdom                                Arc Lamp
# 106  1810                   France                        First Wristwatch
# 155  1831           United Kingdom                      Electric Generator
# 172  1838            United States             oneday brass clock movement
# 183  1840           United Kingdom                               Blueprint
# 186  1841           United Kingdom                      Printing Telegraph
# 193  1845            United States                  Modern Portland Cement
# 195  1846                   France                   Tunnel Boring Machine
# 201  1848            United States                         Pneumatic Drill
# 220  1852                   France                Powered Dirigible Flight
# 223  1854            United States                              Light Bulb
# 238  1859                   France                electric storage battery
# 250  1861  Germany; United Kingdom                      openhearth furnace
# 265  1866                   France                         drycell battery
# 274  1869                   Russia                          Periodic Table
# 290  1876                   Russia              Yablochkov candle arc lamp
# 297  1878            United States                     Electric Light Bulb
# 299  1878           United Kingdom                              rebreather
# 301  1880    Serbia; United States       alternatingcurrent electric motor
# 304  1882            United States                           Iron electric
# 306  1884                   France                                   rayon
# 347  1890            United States                    precut cardboard box
# 397  1904           United Kingdom                  vacuum diode rectifier
# 398  1904           United Kingdom                            Valve; Radio
# 403  1906            United States            Audion vacuum tube amplifier
# 428  1911            United States                      gyroscopic compass
# 445  1915   France; United Kingdom                           military tank
# 447  1915                   France                               Neon Lamp
# 457  1922            United States                                   Radar
# 461  1923    Poland; United States                                   QTips
# 505  1933            United States             portable folding wheelchair
# 514  1935           United Kingdom                     radar early warning
# 538  1943                   France                                AquaLung
# 551  1947            United States             Invention of the transistor
# 564  1948            United States                            atomic clock
# 567  1949            United States  inertial guidance systems for aircraft
# 571  1952                   Sweden                               Pacemaker
# 583  1953                    Japan        video tape recorder helical scan
# 594  1957            United States             laser and optical amplifier
# 596  1957                   Russia          artificial satellite Sputnik 1
# 599  1958            United States                      integrated circuit
# 600  1958            United States                            Optical Disc
# 601  1959       Egypt; South Korea                   MOSFET MOS transistor
# 602  1960            United States                              ruby laser
# 604  1960            United States                 first functioning laser
# 606  1961                  Czechia                     Soft Contact lenses
# 617  1964            United States                  coronary artery bypass
# 636  1970            United States                       pocket calculator
# 637  1971                   Russia                  space station Salyut 1
# 662  1977            United States                         Voyager Program
# 667  1978            United States           Global Positioning System GPS
# 669  1978            United States                                     GPS
# 677  1980                    Japan                            flash memory
# 678  1981            United States                        Laserphaco Probe
# 679  1981                  Germany           scanning tunneling microscope
# 682  1981            United States       Space Shuttle reusable spacecraft
# 686  1982            United States                        Artificial heart
# 690  1983            United States                       stereolithography
# 715  1995       Japan; Netherlands                                     DVD
# 729  2000                    Japan              Bluray optical disc format
# 742  2010                    Japan            solar sail spacecraft IKAROS
#
#                                       Name of Inventor  \
# 7                                   Hsing and LingTsan
# 20    Ewald Georg von Kleist; Pieter van Musschenbroek
# 24                                   Benjamin Franklin
# 40                                NicolasJoseph Cugnot
# 58   JosephMichel Montgolfier; JacquesÉtienne Montg...
# 61                            LouisSébastien Lenormand
# 84                                    Alessandro Volta
# 88                                    Alessandro Volta
# 91                                        Humphry Davy
# 106                               AbrahamLouis Breguet
# 155                                    Michael Faraday
# 172                                    Chauncey Jerome
# 183                                      John Herschel
# 186                                     Alexander Bain
# 193                              Isaac Charles Johnson
# 195                                   HenriJoseph Maus
# 201                                   Jonathan J Couch
# 220                                      Henri Giffard
# 223                                      Thomas Edison
# 238                                       Gaston Plant
# 250                                    William Siemens
# 265                                   Georges Leclanch
# 274                                   Dmitri Mendeleev
# 290                      Pavel Nikolayevich Yablochkov
# 297                                      Thomas Edison
# 299                                       Henry Fleuss
# 301                                       Nikola Tesla
# 304                                     Henry W Seeley
# 306                    Hilaire Bernigaud de Chardonnet
# 347                                        Robert Gair
# 397                               John Ambrose Fleming
# 398                                     Sir JA Fleming
# 403                                      Lee De Forest
# 428                               Elmer Ambrose Sperry
# 445     Walter Wilson; William Tritton; Eugène Brillié
# 447                                     Georges Claude
# 457                    Dr Albert H Taylor  Leo C Young
# 461                                    Leo Gerstenzang
# 505               Harry C Jennings Sr; Herbert Everest
# 514                        Robert Alexander WatsonWatt
# 538                               JacquesYves Cousteau
# 551                      Shockley Bardeen and Brattain
# 564                       National Bureau of Standards
# 567                               Charles Stark Draper
# 571                                      Rune Elmqvist
# 583                                  Norikazu Sawazaki
# 594                       Gordon Gould; Charles Townes
# 596                               Soviet Space Program
# 599                           Jack Kilby; Robert Noyce
# 600                                   David Paul Gregg
# 601                        Mohamed Atalla; Dawon Kahng
# 602                                  Theodore H Maiman
# 604                                    Theodore Maiman
# 606                                     Otto Wichterle
# 617                                    Michael DeBakey
# 636                                  Texas Instruments
# 637                               Soviet Space Program
# 662                                               NASA
# 667                United States Department of Defense
# 669  Roger L Easton; Ivan A Getting; Bradford Parki...
# 677                                      Fujio Masuoka
# 678                                      Patricia Bath
# 679                                        Gerd Binnig
# 682                                               NASA
# 686                                      Robert Jarvik
# 690                                         Chuck Hull
# 715                  Philips; Sony; Toshiba; Panasonic
# 729                                               Sony
# 742                                               JAXA
#
#                                   Category General_Category
# 7                                 Horology            Other
# 20                             Electricity            Other
# 24                             Electricity            Other
# 40                     Military Technology            Other
# 58                               Aerospace            Other
# 61                               Aerospace            Other
# 84                             Electricity            Other
# 88                             Electricity            Other
# 91                             Electricity            Other
# 106                               Horology            Other
# 155                            Electricity            Other
# 172                  Timekeeping Mechanism            Other
# 183                      Technical Drawing            Other
# 186                         Communications            Other
# 193                 Construction Materials            Other
# 195                      Mining Technology            Other
# 201                      Mining Technology            Other
# 220                              Aerospace            Other
# 223                        Lighting Device            Other
# 238                  Energy Storage Device            Other
# 250                  Metallurgical Furnace            Other
# 265                  Energy Storage Device            Other
# 274                       Scientific Model            Other
# 290                        Lighting Device            Other
# 297                        Lighting Device            Other
# 299                      Diving Technology            Other
# 301                         Electric Motor            Other
# 304                    Household Appliance            Other
# 306                          Textile Fiber            Other
# 347                      Industrial Design            Other
# 397                            Electronics            Other
# 398                            Electronics            Other
# 403                            Electronics            Other
# 428                  Navigation Technology            Other
# 445                    Military Technology            Other
# 447                        Lighting Device            Other
# 457                            Electronics            Other
# 461                      Medical Equipment            Other
# 505                      Medical Equipment            Other
# 514                            Electronics            Other
# 538                      Diving Technology            Other
# 551                            Electronics            Other
# 564                 Timekeeping Technology            Other
# 567                  Navigation Technology            Other
# 571                      Medical Equipment            Other
# 583                            Electronics            Other
# 594                        Optoelectronics            Other
# 596                       Space Technology            Other
# 599  Electronics; Semiconductor Technology            Other
# 600                        Optical Storage            Other
# 601               Semiconductor Technology            Other
# 602                       Laser Technology            Other
# 604                       Laser Technology            Other
# 606                      Medical Equipment            Other
# 617                      Medical Equipment            Other
# 636                            Electronics            Other
# 637                       Space Technology            Other
# 662                              Aerospace            Other
# 667                  Navigation Technology            Other
# 669                  Navigation Technology            Other
# 677               Semiconductor Technology            Other
# 678                      Medical Equipment            Other
# 679                         Nanotechnology            Other
# 682                       Space Technology            Other
# 686                      Medical Equipment            Other
# 690                            3D Printing            Other
# 715                        Optical Storage            Other
# 729                        Optical Storage            Other
# 742                       Space Technology            Other

# %%
# Extract, dedupe, and sort the original Category values
unique_categories = sorted(others['Category'].dropna().unique())

# Print them out
print("Unique original Category values among 'Other' rows:")
for cat in unique_categories:
    print(f"- {cat}")
# Out:
# Unique original Category values among 'Other' rows:
# - 3D Printing
# - Aerospace
# - Communications
# - Construction Materials
# - Diving Technology
# - Electric Motor
# - Electricity
# - Electronics
# - Electronics; Semiconductor Technology
# - Energy Storage Device
# - Horology
# - Household Appliance
# - Industrial Design
# - Laser Technology
# - Lighting Device
# - Medical Equipment
# - Metallurgical Furnace
# - Military Technology
# - Mining Technology
# - Nanotechnology
# - Navigation Technology
# - Optical Storage
# - Optoelectronics
# - Scientific Model
# - Semiconductor Technology
# - Space Technology
# - Technical Drawing
# - Textile Fiber
# - Timekeeping Mechanism
# - Timekeeping Technology
